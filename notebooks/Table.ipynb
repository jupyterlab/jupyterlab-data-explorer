# %%
# !pip install -U vega_datasets
# Out:
# Requirement already up-to-date: vega_datasets in /usr/local/miniconda3/envs/jupyterlab-data-explorer/lib/python3.6/site-packages (0.7.0)
# ...

# %%
from vega_datasets import data
import pandas
import datasets

pandas.set_option('display.html.table_schema', True)

# %% [markdown]
# ## URL datatype

# %%
datasets.output_url(
    "https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv"
)

# %% [markdown]
# ## JSON Table Schema

# %%
df = data.iris()
data.cars()
# Out:
#      Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0            12.0          8         307.0       130.0              18.0
# 1            11.5          8         350.0       165.0              15.0
# 2            11.0          8         318.0       150.0              18.0
# 3            12.0          8         304.0       150.0              16.0
# 4            10.5          8         302.0       140.0              17.0
# 5            10.0          8         429.0       198.0              15.0
# 6             9.0          8         454.0       220.0              14.0
# 7             8.5          8         440.0       215.0              14.0
# 8            10.0          8         455.0       225.0              14.0
# 9             8.5          8         390.0       190.0              15.0
# 10           17.5          4         133.0       115.0               NaN
# 11           11.5          8         350.0       165.0               NaN
# ...

# %% [markdown]
# ## File Dataset

# %%
datasets.output_pandas(df)
